# %%
import pandas as pd
import numpy as np

# %%
data_file = pd.read_csv('/Users/miafusco/Documents/LaunchCode/data-analysis-projects2/IMDB-Movie-Data.csv')

# %%
data_indexed=data_file.set_index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year','Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)','Metascore'])

# %%
data_file = pd.read_csv('/Users/miafusco/Documents/LaunchCode/data-analysis-projects2/data-manipulation/exercises/titanic.csv')
data_file.head(5)
grouping_variable = data_file.groupby("embark_town")
grouping_variable.first()
# Out:
#              survived  pclass     sex   age  sibsp  parch     fare embarked  \
# embark_town
# Cherbourg           1       1  female  38.0      1      0  71.2833        C
# Queenstown          0       3    male   2.0      0      0   8.4583        Q
# Southampton         0       3    male  22.0      1      0   7.2500        S
#
#              class    who  adult_male deck alive  alone
# embark_town
# Cherbourg    First  woman       False    C   yes  False
# Queenstown   Third    man        True    C    no   True
# Southampton  Third    man        True    C    no  False

# %%
people_survived = data_file.groupby("survived")
people_survived.first()
# Out:
#           pclass     sex   age  sibsp  parch     fare embarked  class    who  \
# survived
# 0              3    male  22.0      1      0   7.2500        S  Third    man
# 1              1  female  38.0      1      0  71.2833        C  First  woman
#
#           adult_male deck  embark_town alive  alone
# survived
# 0               True    E  Southampton    no  False
# 1              False    C    Cherbourg   yes  False

# %%
people_survived.describe()
# Out:
#          pclass                                                 age  \
#           count      mean       std  min  25%  50%  75%  max  count
# survived
# 0         549.0  2.531876  0.735805  1.0  2.0  3.0  3.0  3.0  424.0
# 1         342.0  1.950292  0.863321  1.0  1.0  2.0  3.0  3.0  290.0
#
#                      ... parch        fare                             \
#                mean  ...   75%  max  count       mean        std  min
# survived             ...
# 0         30.626179  ...   0.0  6.0  549.0  22.117887  31.388207  0.0
# 1         28.343690  ...   1.0  5.0  342.0  48.395408  66.596998  0.0
#
#
#               25%   50%   75%       max
# survived
# 0          7.8542  10.5  26.0  263.0000
# 1         12.4750  26.0  57.0  512.3292
#
# [2 rows x 40 columns]

# %%
data_file = pd.read_csv('/Users/miafusco/Documents/LaunchCode/data-analysis-projects2/data-manipulation/exercises/titanic.csv')
data_file.head(5)
pclass_group = data_file.groupby("pclass")
pclass_group.first()
grouping_variable = data_file.groupby("embark_town")
grouping_variable.first()
age_dictionary={"age":["sum", "max"]}
dictionary_agg=grouping_variable.agg(age_dictionary)
dictionary_agg
# Out:
#                   age
#                   sum   max
# embark_town
# Cherbourg     4005.92  71.0
# Queenstown     786.50  70.5
# Southampton  16312.75  80.0

# %%
new_dictionary = {"age":["sum", "max"], "sex":["count"]}
dictionary_agg = grouping_variable.agg(new_dictionary)
dictionary_agg
# Out:
#                   age         sex
#                   sum   max count
# embark_town
# Cherbourg     4005.92  71.0   168
# Queenstown     786.50  70.5    77
# Southampton  16312.75  80.0   644

# %%
new_dictionary2 = {"age":["std", "min"], "survived":["sum", "count"], "sibsp":["count", "sum"]}
dictionary_agg = grouping_variable.agg(new_dictionary2)
dictionary_agg
# Out:
#                    age       survived       sibsp
#                    std   min      sum count count  sum
# embark_town
# Cherbourg    15.434860  0.42       93   168   168   65
# Queenstown   16.915396  2.00       30    77    77   33
# Southampton  14.143192  0.67      217   644   644  368

# %%
data_file = pd.read_csv('/Users/miafusco/Documents/LaunchCode/data-analysis-projects2/data-manipulation/exercises/titanic.csv')
grouping_variable = data_file.groupby("alive")
grouping_variable["alive_reformatted"] = grouping_variable["alive"].replace[{0: False, 1: True}]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 3
#       1 data_file = pd.read_csv('/Users/miafusco/Documents/LaunchCode/data-analysis-projects2/data-manipulation/exercises/titanic.csv')
#       2 grouping_variable = data_file.groupby("alive")
# ----> 3 grouping_variable["alive_reformatted"] = grouping_variable["alive"].replace[{0: False, 1: True}]
#
# File ~/Documents/LaunchCode/data-analysis-projects2/virtual/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'replace'
