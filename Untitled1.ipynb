# %%
import pandas as pd
import numpy as np
data_file = pd.read_csv('/Users/miafusco/Documents/LaunchCode/data-analysis-projects2/cleaning-data-with-pandas/studio/san-fransisco_9-24-2016_9-30-2017.csv')

# %%
data_file.head()
# Out:
#   Commodity Name      City Name Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  SAN FRANCISCO  NaN  24 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  SAN FRANCISCO  NaN  24 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  SAN FRANCISCO  NaN  24 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  SAN FRANCISCO  NaN  24 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  SAN FRANCISCO  NaN  24 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  09/24/2016      155.0       155.0  ...    NaN          NaN
# 1    NaN  10/01/2016      155.0       155.0  ...    NaN          NaN
# 2    NaN  10/01/2016      155.0       155.0  ...    NaN          NaN
# 3    NaN  10/01/2016      135.0       135.0  ...    NaN          NaN
# 4    NaN  10/08/2016      135.0       150.0  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition Appearance  Storage  Crop  Repack  \
# ...

# %%
for col in data_file.columns:
    pct_missing = np.mean(data_file[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 78%
# Package - 0%
# Variety - 0%
# Sub Variety - 61%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 100%
# Item Size - 75%
# Color - 72%
# Environment - 100%
# Unit of Sale - 100%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
total_cells = np.product(data_file.shape)

missing_cells = pd.isnull(data_file).sum()

total_missing = missing_cells.sum()

percentage_missing = round((total_missing/total_cells), 2) *100

print(percentage_missing, "% Missing cells from the data")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 total_cells = np.product(data_file.shape)
#       3 missing_cells = pd.isnull(data_file).sum()
#       5 total_missing = missing_cells.sum()
#
# File ~/Documents/LaunchCode/data-analysis-projects2/virtual/lib/python3.12/site-packages/numpy/__init__.py:414, in __getattr__(attr)
#     411     import numpy.char as char
#     412     return char.chararray
# --> 414 raise AttributeError("module {!r} has no attribute "
#     415                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'product'

# %%
# Repack Column
data_file["Repack"] = data_file["Repack"].replace({"N":False})
#Check status with a quick head check
data_file.head(3)
# Out:
#   Commodity Name      City Name Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  SAN FRANCISCO  NaN  24 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  SAN FRANCISCO  NaN  24 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  SAN FRANCISCO  NaN  24 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  09/24/2016      155.0       155.0  ...    NaN          NaN
# 1    NaN  10/01/2016      155.0       155.0  ...    NaN          NaN
# 2    NaN  10/01/2016      155.0       155.0  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition Appearance  Storage  Crop  Repack  \
# 0          NaN      NaN       NaN        NaN      NaN   NaN   False
# 1          NaN      NaN       NaN        NaN      NaN   NaN   False
# 2          NaN      NaN       NaN        NaN      NaN   NaN   False
#
#    Trans Mode
# 0         NaN
# 1         NaN
# 2         NaN
#
# [3 rows x 25 columns]

# %%
# Fill the Missing Values in the Type Column
data_file["Type"] = data_file["Type"].fillna("Conventional")
print(type)
print(data_file.Type)
# Out:
# <class 'type'>
# 0      Conventional
# 1      Conventional
# 2      Conventional
# 3      Conventional
# 4      Conventional
#            ...
# 161    Conventional
# 162    Conventional
# 163    Conventional
# 164    Conventional
# 165    Conventional
# Name: Type, Length: 166, dtype: object

# %%
data_file = data_file.drop(["Grade"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 data_file = data_file.drop(["Grade"], axis=1)
#
# File ~/Documents/LaunchCode/data-analysis-projects2/virtual/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
data_file.shape
# Out:
# (166, 24)

# %%
data_file.head()
# Out:
#   Commodity Name      City Name          Type       Package      Variety  \
# 0       PUMPKINS  SAN FRANCISCO  Conventional  24 inch bins  HOWDEN TYPE
# 1       PUMPKINS  SAN FRANCISCO  Conventional  24 inch bins  HOWDEN TYPE
# 2       PUMPKINS  SAN FRANCISCO  Conventional  24 inch bins  HOWDEN TYPE
# 3       PUMPKINS  SAN FRANCISCO  Conventional  24 inch bins  HOWDEN TYPE
# 4       PUMPKINS  SAN FRANCISCO  Conventional  24 inch bins  HOWDEN TYPE
#
#   Sub Variety        Date  Low Price  High Price  Mostly Low  ...  Color  \
# 0         NaN  09/24/2016      155.0       155.0       155.0  ...    NaN
# 1         NaN  10/01/2016      155.0       155.0       155.0  ...    NaN
# 2         NaN  10/01/2016      155.0       155.0       155.0  ...    NaN
# 3         NaN  10/01/2016      135.0       135.0       135.0  ...    NaN
# 4         NaN  10/08/2016      135.0       150.0       135.0  ...    NaN
#
#   Environment  Unit of Sale Quality Condition  Appearance  Storage  Crop  \
# ...

# %%
data_file = data_file.drop(["Trans Mode"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 data_file = data_file.drop(["Trans Mode"], axis=1)
#
# File ~/Documents/LaunchCode/data-analysis-projects2/virtual/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
data_file= ['Date'].value_counts().plot.bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 data_file= ['Date'].value_counts().plot.bar()
#
# AttributeError: 'list' object has no attribute 'value_counts'

# %%
data_file['Date'].hist(bins=100)
plt.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 data_file['Date'].hist(bins=100)
#       2 plt.xticks(rotation=90)
#
# File ~/Documents/LaunchCode/data-analysis-projects2/virtual/lib/python3.12/site-packages/pandas/plotting/_core.py:128, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      47 def hist_series(
#      48     self: Series,
#      49     by=None,
#    (...)
#      60     **kwargs,
#      61 ):
#      62     """
#      63     Draw histogram of the input series using matplotlib.
#      64
#    (...)
#     126         >>> hist = ser.groupby(level=0).hist()
#     127     """
# --> 128     plot_backend = _get_plot_backend(backend)
#     129     return plot_backend.hist_series(
#     130         self,
#     131         by=by,
#    (...)
#     141         **kwargs,
# ...
